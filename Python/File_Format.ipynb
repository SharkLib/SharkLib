# %%
# -*- coding:UTF-8 -*-
#file1 = open("/Users/rong/work/git/sharklib.github.io/_posts/stories/" + x.strftime("%Y-%m-%d-MyStory") + str(num) + ".md","a")


from os import listdir
from os.path import isfile, join
peom_path = "/Users/rong/work/poems"
onlyfiles = [f for f in listdir(peom_path) if isfile(join(peom_path, f))]
for name in onlyfiles:
    print (name)
    if ( name.startswith(".")==True):
        continue
    p = open(peom_path + "/" + name,"r")
    Lines = p.readlines() 
    
    poem = ''
    author = ''
    title = ''
    description =''
    extension1 = ''
    extension2 = ''
    for line in Lines: 
        if ( (line.strip() is not "") & (line.strip().startswith("注释")==False) 
            & (line.strip().startswith("赏析")==False) & (line.strip().startswith("译文及注释")==False)
           & (line.strip().startswith("展开阅读全文")==False)):
            #print(line.strip()) 
            if (title ==''):
                #print(line)
                aa = line.split('——')
                #print(aa)
                bb = aa[1].split('《')
                poem = aa[0]
                title = bb[1].split('》')[0]
                if ("/" in title ):
                    title = title.split("/")[0]
                author = bb[0]
                #print(poem,title,author)
            elif (description  == ''):
                #print (line)
                if (line.strip() is not '赏析'):
                    description = line.strip() 
            elif (extension1 == ""):
                #print (line)
                extension1 =  line.strip() 
            elif (extension2 == ""):
                #print (line)
                extension2 =  line.strip() 
            else:
                break;
    #print(title)
    json_file = open("/Users/rong/work/poems/json/" + title + ".json","a")    
    json_file.write("{\n")
    json_file.write("\"title\":\"" + title + "\",\n")
    json_file.write("\"poem\":\"" + poem + "\",\n")
    json_file.write("\"description\":\"" + description + "\",\n")
    json_file.write("\"extension1\":\"" + extension1 + "\",\n")
    json_file.write("\"extension2\":\"" + extension2 + "\"\n")
    json_file.write("}\n")
    json_file.close()
    #print( title, author,poem,description ,extension1)
        #print("------")
        #print("Line{}: {}".format(count, line.strip()))
# Out:
# 送杜少府之任蜀州.md
# 金陵图.md
# 章台夜思.md
# 枫桥夜泊.md
# 塞下曲·鹫翎金仆姑.md
# 近试上张水部.md
# 寻隐者不遇.md
# 芙蓉楼送辛渐.md
# 听筝.md
# 送崔九.md
# 丹青引赠曹霸将军.md
# 留别王维.md
# 谷口书斋寄杨补阙.md
# 长相思·其二.md
# 贼平后送人北归.md
# 鹿柴.md
# 秦中寄远上人.md
# 感遇·幽人归独卧.md
# 江乡故人偶集客舍.md
# 秋日赴阙题潼关驿楼.md
# 凉州词.md
# 终南望余雪.md
# 游子吟.md
# 蜀先主庙.md
# 望岳.md
# 宫中词.md
# 听弹琴.md
# 玉台体.md
# 隋宫.md
# 春宫怨.md
# 送梓州李使君.md
# 哀江头.md
# 宿府.md
# 和贾至舍人早朝大明宫.md
# 望蓟门.md
# .DS_Store
# 贫女.md
# 落花.md
# 寄李儋元锡.md
# 夏日南亭怀辛大.md
# 山中送别.md
# 韩碑.md
# 遣悲怀三首·其三.md
# 喜见外弟又言别.md
# 竹里馆.md
# 寻陆鸿渐不遇.md
# 出塞·秦时明月汉时关.md
# 送别.md
# 春词.md
# 将赴吴兴登乐游原一绝.md
# 谒衡岳庙遂宿岳寺题门楼.md
# 桃花溪.md
# 客至.md
# 赠孟浩然.md
# 九日登望仙台呈刘明府.md
# 题大庾岭北驿.md
# 山石.md
# 将进酒.md
# 寄左省杜拾遗.md
# 送綦毋潜落第还乡.md
# 独不见.md
# 登乐游原.md
# 春怨.md
# 后宫词.md
# 渭川田家.md
# 新嫁娘词.md
# 无题·来是空言去绝踪.md
# 登柳州城楼寄漳汀封连四州.md
# 与诸子登岘山.md
# 江雪.md
# 长干行·家临九江水.md
# 喜外弟卢纶见宿.md
# 陇西行.md
# 岁暮归南山.md
# 黄鹤楼送孟浩然之广陵.md
# 相思.md
# 春宿左省.md
# 长相思·其一.md
# 蜀相.md
# 楚江怀古三首·其一.md
# 山居秋暝.md
# 瑶池.md
# 送杨氏女.md
# 赤壁.md
# 春宫曲.md
# 春雨.md
# 秋登兰山寄张五.md
# 为有.md
# 利州南渡.md
# 石鱼湖上醉歌.md
# 阙题.md
# ...

# %%
# -*- coding:UTF-8 -*-
#file1 = open("/Users/rong/work/git/sharklib.github.io/_posts/stories/" + x.strftime("%Y-%m-%d-MyStory") + str(num) + ".md","a")


from os import listdir
from os.path import isfile, join
peom_path = "/Users/rong/work/ci"
onlyfiles = [f for f in listdir(peom_path) if isfile(join(peom_path, f))]
for name in onlyfiles:
    print (name)
    if ( name.startswith(".")==True):
        continue
    p = open(peom_path + "/" + name,"r")
    Lines = p.readlines() 
    
    poem = ''
    author = ''
    title = ''
    description =''
    extension1 = ''
    extension2 = ''
    for line in Lines: 
        if ( (line.strip() is not "") & (line.strip().startswith("注释")==False) 
            & (line.strip().startswith("赏析")==False) & (line.strip().startswith("译文及注释")==False)
           & (line.strip().startswith("展开阅读全文")==False)):
            #print(line.strip()) 
            if (title ==''):
                #print(line)
                aa = line.split('——')
                #print(aa)
                bb = aa[1].split('《')
                poem = aa[0]
                title = bb[1].split('》')[0]
                if ("/" in title ):
                    title = title.split("/")[0]
                author = bb[0]
                #print(poem,title,author)
            elif (description  == ''):
                #print (line)
                if (line.strip() is not '赏析'):
                    description = line.strip() 
            elif (extension1 == ""):
                #print (line)
                extension1 =  line.strip() 
            elif (extension2 == ""):
                #print (line)
                extension2 =  line.strip() 
            else:
                break;
    #print(title)
    json_file = open("/Users/rong/work/ci/json/" + title + ".json","a")    
    json_file.write("{\n")
    json_file.write("\"title\":\"" + title + "\",\n")
    json_file.write("\"poem\":\"" + poem + "\",\n")
    json_file.write("\"description\":\"" + description + "\",\n")
    json_file.write("\"extension1\":\"" + extension1 + "\",\n")
    json_file.write("\"extension2\":\"" + extension2 + "\"\n")
    json_file.write("}\n")
    json_file.close()
    #print( title, author,poem,description ,extension1)
        #print("------")
        #print("Line{}: {}".format(count, line.strip()))
# Out:
# 唐多令·芦叶满汀洲.md
# 瑞龙吟·大石春景.md
# 踏莎行·候馆梅残.md
# 相见欢·金陵城上西楼.md
# 捣练子令·深院静.md
# 踏莎行·秋入云山.md
# 六丑·落花.md
# 鹧鸪天·寒日萧萧上琐窗.md
# 酒泉子·长忆观潮.md
# 卜算子·见也如何暮.md
# 渔家傲·天接云涛连晓雾.md
# 水龙吟·次韵章质夫杨花词.md
# 如梦令·昨夜雨疏风骤.md
# 蝶恋花·槛菊愁烟兰泣露.md
# 望江南·天上月.md
# 六州歌头·长淮望断.md
# 疏影·苔枝缀玉.md
# 浪淘沙·莫上玉楼看.md
# 暗香·旧时月色.md
# 相见欢·无言独上西楼.md
# 诉衷情·当年万里觅封侯.md
# 忆秦娥·箫声咽.md
# 菩萨蛮·书江西造口壁.md
# 武陵春·春晚.md
# 水龙吟·春恨.md
# 渔家傲·小雨纤纤风细细.md
# 蝶恋花·送春.md
# 定风波·自春来.md
# 小重山·昨夜寒蛩不住鸣.md
# 风入松·一春长费买花钱.md
# 石州引·薄雨初寒.md
# 江神子·杏花村馆酒旗风.md
# 念奴娇·赤壁怀古.md
# 南乡子·乘彩舫.md
# 浣溪沙·一曲新词酒一杯.md
# 贺新郎·送胡邦衡.md
# 秋蕊香·帘幕疏疏风透.md
# 菩萨蛮·枕前发尽千般愿.md
# 点绛唇·感兴.md
# 蝶恋花·春涨一篙添水面.md
# .DS_Store
# 半死桐·重过阊门万事非.md
# 南柯子·山冥云阴重.md
# 秦楼月·芳菲歇.md
# 如梦令·常记溪亭日暮.md
# 永遇乐·京口北固亭怀古.md
# 鹊桥仙·纤云弄巧.md
# 菩萨蛮·平林漠漠烟如织.md
# 山亭柳·赠歌者.md
# 长命女·春日宴.md
# 千秋岁·水边沙外.md
# 离亭燕·一带江山如画.md
# 一剪梅·舟过吴江.md
# 思越人·紫府东风放夜时.md
# 莺啼序·春晚感怀.md
# 绮罗香·咏春雨.md
# 湘春夜月·近清明.md
# 定风波(苏轼).md
# 浣溪沙·蓼岸风多橘柚香.md
# 夜游宫·叶下斜阳照水.md
# 江城子·西城杨柳弄春柔.md
# 满江红·写怀.md
# 丑奴儿·书博山道中壁.md
# 昭君怨·赋松上鸥.md
# 一剪梅·红藕香残玉簟.md
# 临江仙·梦后楼台高锁.md
# 定风波·莫听穿林打叶声.md
# ...

# %%
from os import listdir
from os.path import isfile, join
peom_path = "/Users/rong/work/git/flutter/dailychinese/assets/shi_json"
onlyfiles = [f for f in listdir(peom_path) if isfile(join(peom_path, f))]
for name in onlyfiles:
    print('\"'+name+'\",')
# Out:
# "次北固山下.json",
# "宿王昌龄隐居.json",
# "送魏万之京.json",
# "过故人庄.json",
# "长干行·君家何处住.json",
# "石鱼湖上醉歌.json",
# "酬程延秋夜即事见赠.json",
# "归嵩山作.json",
# "饯别王十一南游.json",
# "西施咏.json",
# "长干行·其一.json",
# "秋夕.json",
# "早秋三首·其一.json",
# "寄扬州韩绰判官.json",
# "感遇十二首·其二.json",
# "咏蝉.json",
# "草 .json",
# "江南曲.json",
# "春宫怨.json",
# "同题仙游观.json",
# "回乡偶书.json",
# "石鼓歌.json",
# "清平调·其一.json",
# "游子吟.json",
# "关山月.json",
# "灞上秋居.json",
# "月下独酌四首·其一.json",
# "琴歌.json",
# "春怨 .json",
# "题大庾岭北驿.json",
# "秋登万山寄张五.json",
# "喜外弟卢纶见宿.json",
# "喜见外弟又言别.json",
# "奉和中书舍人贾至早朝大明宫.json",
# "没蕃故人.json",
# "长相思·其二.json",
# "蝉.json",
# "琵琶行并序.json",
# "已凉.json",
# "泊秦淮.json",
# "登柳州城楼寄漳汀封连四州.json",
# "兵车行.json",
# "桃源行.json",
# "为有.json",
# "送杜少府之任蜀州.json",
# ".DS_Store",
# "贼平后送人北归.json",
# "利州南渡.json",
# "终南别业.json",
# "山石.json",
# "行路难·其一.json",
# "近试上张籍水部.json",
# "玉台体.json",
# "蜀道难.json",
# "题金陵渡.json",
# "九月九日忆山东兄弟.json",
# "嫦娥.json",
# "和张仆射塞下曲·其一.json",
# "无题·来是空言去绝踪.json",
# "清平调·名花倾国两相欢.json",
# "哥舒歌.json",
# ...

# %%
# -*- coding:UTF-8 -*-
# 谚语
import requests
import datetime
from bs4 import BeautifulSoup

def do(url):
    
    target = url

    req = requests.get(url=target)
    html = req.text
    bf = BeautifulSoup(html)
    texts = bf.find_all('div', class_ = 'bbs-content') 
    #print(texts[0].text.replace('\xa0'*8,'\n\n'))
    num = 0
    for text in texts:
        #print(text)
        x =  datetime.date.today()

        aa = text.text.split("《")
        if len(aa)<2:
            continue
        bb = aa[1].split("》")

        file1 = open("/Users/rong/work/yanyu/" + bb[0] + ".json","a") 

        file1.write(str(text.text))

        file1.close()
        #break;
    print("done")   
    
target = 'http://bbs.tianya.cn/post-free-5681731-{0}.shtml'
for num in range(1,28):
    uu = target.format(num)
    print(uu)
    do(uu)
# Out:
# http://bbs.tianya.cn/post-free-5681731-1.shtml
# done
# http://bbs.tianya.cn/post-free-5681731-2.shtml
# done
# http://bbs.tianya.cn/post-free-5681731-3.shtml
# done
# http://bbs.tianya.cn/post-free-5681731-4.shtml
# done
# http://bbs.tianya.cn/post-free-5681731-5.shtml
# done
# http://bbs.tianya.cn/post-free-5681731-6.shtml
# done
# http://bbs.tianya.cn/post-free-5681731-7.shtml
# done
# http://bbs.tianya.cn/post-free-5681731-8.shtml
# done
# http://bbs.tianya.cn/post-free-5681731-9.shtml
# done
# http://bbs.tianya.cn/post-free-5681731-10.shtml
# done
# http://bbs.tianya.cn/post-free-5681731-11.shtml
# done
# http://bbs.tianya.cn/post-free-5681731-12.shtml
# done
# http://bbs.tianya.cn/post-free-5681731-13.shtml
# done
# http://bbs.tianya.cn/post-free-5681731-14.shtml
# done
# http://bbs.tianya.cn/post-free-5681731-15.shtml
# done
# http://bbs.tianya.cn/post-free-5681731-16.shtml
# done
# http://bbs.tianya.cn/post-free-5681731-17.shtml
# done
# ...

# %%
import os
import sys
pa = "/Users/rong/work/poems/mp3/QTDownloadRadio/"
file1 = open("/Users/rong/work/poems/mp3/QTDownloadRadio/download.dat","r") 
Lines = file1.readlines() 
for line in Lines:
    #   print(line)
    items = line.split('@')
    #print(items[1], items[6])
    if ( "唐诗三百首" in items[6]):
        sub_items = items[6].split(".")
        #print(sub_items)
        print(sub_items[3])
        os.rename(pa+ items[1],pa+ sub_items[3] +".mp3") # rename the file
    else:
        print(items[6])
    print(items[1])
    
    
def renameFun(dirr):
    stt = "(1)"
    for filename in os.listdir (dirr): # parse through file list in the folder "test"
        if filename.find(stt) > 0: # if an .jpg is found
            newfilename = filename.replace(stt,"") # convert .jpg to jpeg
            #os.rm(dirr + "/" + filename, dirr + "/" + newfilename) # rename the file
            os.remove(dirr + "/" + filename) # rename the file
# Out:
# 夫妻互怼，才是最高级的秀恩爱
# 13917024
# 你的坐姿，影响你的寿命
# 13917020
# 半生已过，学会幽默
# 13916967
# 你控制不了情绪，怎么过好一生
# 13917025
# 最好的余生：有家回，有人等.
# 13917022
# 最怕在某个年纪，听懂一首歌
# 13916847
# 拿什么保护你，我的女儿？
# 13917021
# 你会遇见谁，早就命中注定了
# 13917019
# 不读书，凭什么过上想要的生活
# 13917017
# 人到中年，要忘掉3件事
# 13917018
# 想放弃时，请读读老师这9句话
# 13916845
# 嫁给那个愿意陪你好好吃饭的人
# 13894923
# 读书很苦，那就尝尝无知的代价
# 13906909
# 人到中年，越活越“抠”
# 13906906
# 如果人生太难，就去医院走走
# 13916846
# 变胖，是对工作最起码的尊重
# 13894924
# 夫妻说话，暴露了婚姻的本质
# 13906907
# “我特别害怕胡歌这样的人”
# 13875966
# 这一年，我是哭着过完的
# 13875964
# 成年人的绝交，都是静悄悄
# 13865894
# 好的婚姻，要学会做减法
# 13865893
# 情商高的人，从不这么发微信
# 13875965
# 有一种高级的情商，叫不抬杠
# 13894922
# 养育是一场相互滋养
# 13848147
# 好的关系，都是“麻烦”出来的
# 13848146
# 讨厌一个人，用不着翻脸
# 13865892
# 不经意的细节，出卖你的教养
# 13848145
# 女人的崩溃，往往只在一瞬间
# 13848129
# 最高级的修养，叫遇事不指责
# 13848133
# 结婚，真的要看家境
# 13848139
# （03）美丽的相遇
# 3217862
# （01）追踪桑德尔公鹿
# 3217860
# （05）又差一点点
# 3217864
# （07）漫长的较量
# 3217866
# （04）陷入狼群的包围
# 3217863
# （06）公鹿的妻子
# 3217865
# （02）神奇的脚印
# 3217861
# （08）最后的追捕
# 3217867
# 第08首：重归苏莲托
# 4525050
# ...

# %%
# -*- coding:UTF-8 -*-
from os import listdir
from os.path import isfile, join
peom_path = "/Users/rong/work/yanyu"
onlyfiles = [f for f in listdir(peom_path) if isfile(join(peom_path, f))]
allON = open( "/Users/rong/work/all.txt" ,"w")
lastline = ''
for name in onlyfiles:
    if ( name.startswith(".")==True):
        continue
    print(name)
    p = open(peom_path + "/" + name,"r")
    Lines = p.readlines() 
    for line in Lines:
        ll = line.strip()
        if ( (ll is not "") & ( ll is not lastline )   ) :
            lastline = ll
            allON.write(ll + "\n")
# Out:
# 忍耐.json
# 宁可信其有，不可信其无 (2).json
# 被关进精神病院的耶稣.json
# 失败 (2).json
# 质与量.json
# 感同身受.json
# 毒药.json
# 学走路的小孩.json
# 两害相权取其轻.json
# 智慧人.json
# 共同的仇敌.json
# 救人.json
# 耶稣的再临 (3).json
# 宇宙.json
# 审判 (2).json
# 阴阳平衡.json
# 时间停止的地狱.json
# 智者与愚人.json
# 成功与失败（2）.json
# 天堂墓地.json
# 鸟与鸡.json
# 做人与做事（4）.json
# 错误.json
# 密室.json
# 人生任务 (3).json
# 真理.json
# 善辩者无真理.json
# 善良.json
# 身不由己.json
# 行善与作恶.json
# 有福.json
# 方丈的两个徒弟.json
# 死亡与地狱.json
# 污秽.json
# 人类的进程.json
# 不亏.json
# 无奈的上帝.json
# 上帝的国度未必降临.json
# 信与诚（2）.json
# 主观与客观.json
# 大臣的谏言.json
# 法官.json
# 祷告 (4).json
# 自家的泳池.json
# 喝水与吃饭.json
# 扶持正念.json
# 信 (4).json
# 诺亚方舟（2）.json
# 全世界最棒与全世界最差.json
# 做事三步骤.json
# 幸福与痛苦.json
# 宗教差异.json
# 定位.json
# 好人与恶人.json
# 对不起.json
# 正念.json
# 善良人的标准.json
# 人权与神权.json
# 正信与迷信.json
# 好学生.json
# “慈善”的商人.json
# 耶稣二次降临之前.json
# 黑暗与光明（2）.json
# 假基督徒.json
# 试炼（2）.json
# 重于泰山的生与轻于鸿毛的死.json
# 不说情的耶稣.json
# 换位思考.json
# 自我教育和自我管理.json
# 善良是迈向高等文明的基础.json
# 被撕毁的圣经.json
# 爱与怕.json
# 修行（14）.json
# 赏与惩.json
# 穷与富.json
# ...
